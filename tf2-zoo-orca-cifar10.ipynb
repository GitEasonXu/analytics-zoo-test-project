# %% [markdown]
# ## 计算机视觉：图像分类
#
# ### 项目介绍：基于Analytics-Zoo Orca on yarn 分布式框架训练图像分类模型
# ### 1.导入模块，初始化运行环境

# %%
import tensorflow as tf
from zoo.orca import init_orca_context, stop_orca_context
from zoo.orca.learn.tf2 import Estimator
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /root/anaconda3/envs/zoo-tf2.3/lib/python3.6/site-packages/bigdl/util/engine.py:41: UserWarning: Find both SPARK_HOME and pyspark. You may need to check whether they match with each other. SPARK_HOME environment variable is set to: /usr/local/spark2, and pyspark is found in: /root/anaconda3/envs/zoo-tf2.3/lib/python3.6/site-packages/pyspark/__init__.py. If they are unmatched, please use one source only to avoid conflict. For example, you can unset SPARK_HOME and use pyspark only.
#   warnings.warn(warning_msg)
# /root/anaconda3/envs/zoo-tf2.3/lib/python3.6/site-packages/zoo/util/engine.py:42: UserWarning: Find both SPARK_HOME and pyspark. You may need to check whether they match with each other. SPARK_HOME environment variable is set to: /usr/local/spark2, and pyspark is found in: /root/anaconda3/envs/zoo-tf2.3/lib/python3.6/site-packages/pyspark/__init__.py. If they are unmatched, you are recommended to use one source only to avoid conflict. For example, you can unset SPARK_HOME and use pyspark only.
#   warnings.warn(warning_msg)
# Prepending /root/anaconda3/envs/zoo-tf2.3/lib/python3.6/site-packages/bigdl/share/conf/spark-bigdl.conf to sys.path
# Adding /root/anaconda3/envs/zoo-tf2.3/lib/python3.6/site-packages/zoo/share/lib/analytics-zoo-bigdl_0.12.1-spark_2.4.3-0.9.0-SNAPSHOT-jar-with-dependencies.jar to BIGDL_JARS
# Prepending /root/anaconda3/envs/zoo-tf2.3/lib/python3.6/site-packages/zoo/share/conf/spark-analytics-zoo.conf to sys.path

# %%
## 更新系统的环境变量
import os
print(os.environ["PATH"])
# Out:
# /root/anaconda3/envs/zoo-tf2.3/bin:/root/anaconda3/bin:/root/anaconda3/bin:/usr/jdk64/java/bin:/usr/hdp/3.0.1.0-187/hadoop/bin:/usr/local/spark2/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin

# %% [markdown]
# ### 2.载入cifar10数据集

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()
print("Train datasets shape: ", train_images.shape)
print("Train labels shape: ", train_labels.shape)

image_shape = tuple(train_images.shape[1:])
# Out:
# Train datasets shape:  (50000, 32, 32, 3)
# Train labels shape:  (50000, 1)

# %% [markdown]
# ### 3.数据分析
# #### 3.1原始数据可视化

# %%
plt.figure(figsize=(16,4))
for i in range(16):
    plt.subplot(2,8,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %% [markdown]
# #### 3.2数据增广以及可视化

# %%
import numpy as np
def preprocess_image(image, label):
    #Color augmentation
    x = tf.image.random_hue(image, 0.3)
    x = tf.image.random_saturation(x, 0.6, 1.6)
    x = tf.image.random_brightness(x, 0.3)
    x = tf.image.random_contrast(x, 0.7, 1.3)
    #Flip
    x = tf.image.random_flip_left_right(x)
    x = tf.image.random_flip_up_down(x)
    #Random crop
    x = tf.image.random_crop(x,size=[int(image_shape[0] * 0.9), int(image_shape[1] * 0.9), 3])
    x = tf.image.resize(x, [image_shape[0], image_shape[1]])
    return x, label

dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
dataset = dataset.map(preprocess_image, num_parallel_calls=2).batch(1)
iter_dataset = iter(dataset)
plt.figure(figsize=(16,4))
for i in range(16):
    image,label = iter_dataset.get_next()
    image = image.numpy().astype(np.uint8)
    plt.subplot(2,8,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(image[0], cmap=plt.cm.binary)
    plt.xlabel(class_names[label[0][0]])
plt.show()
del dataset

# %%
from imgaug import augmenters as iaa
seq = iaa.Sequential([
            iaa.Fliplr(0.5),
            iaa.Affine(translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
                       shear={"x": (-1, 1), "y": (-1, 1)},
                       scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},
                       rotate=(-10, 10)
                       ),
            iaa.MultiplyAndAddToBrightness(mul=(0.5, 1.5), add=(-30, 30), from_colorspace="RGB"),
            iaa.MultiplyHueAndSaturation(mul_hue=(0.5, 1.5)),
            iaa.Resize({"height": image_shape[0], "width": image_shape[1]})
        ])

# %%
def image_aug(image):
    result = seq(image=image.numpy())
    #bn_image = result.astype(np.float32) / 255.
    return result
def preprocess_image(x, y):
    x = tf.py_function(image_aug, [x], tf.float32)
    return x, y

dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
dataset = dataset.map(preprocess_image, num_parallel_calls=2).batch(1)
iter_dataset = iter(dataset)
plt.figure(figsize=(16,4))
for i in range(16):
    image,label = iter_dataset.get_next()
    image = image.numpy().astype(np.uint8)
    plt.subplot(2,8,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(image[0], cmap=plt.cm.binary)
    plt.xlabel(class_names[label[0][0]])
plt.show()
del dataset

# %% [markdown]
# ### 4.构建数据预处理Pipeline

# %%
def train_preprocess(x, y):
    #Color augmentation
    x = tf.image.random_hue(x, 0.3)
    x = tf.image.random_saturation(x, 0.6, 1.6)
    x = tf.image.random_brightness(x, 0.3)
    x = tf.image.random_contrast(x, 0.7, 1.3)
    #Flip
    x = tf.image.random_flip_left_right(x)
    x = tf.image.random_flip_up_down(x)
    #Random crop
    x = tf.image.random_crop(x,size=[int(image_shape[0] * 0.9), int(image_shape[1] * 0.9), 3])
    x = tf.cast(tf.image.resize(x, [image_shape[0], image_shape[1]]), dtype=tf.float32) / 255.0
    return x, y
def image_aug(image):
    result = seq(image=image.numpy())
    result = result.astype(np.float32) / 255.
    return result
def train_preprocess_aug(x, y):
    x = tf.py_function(image_aug, [x], tf.float32)
    return x, y

def test_preprocess(x, y):
    x = tf.cast(tf.image.resize(x, [image_shape[0], image_shape[1]]), dtype=tf.float32) / 255.0
    return x, y


def train_data_creator(config):
    global train_images, train_labels
    dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
    dataset = dataset.repeat()
    dataset = dataset.map(train_preprocess)
    dataset = dataset.shuffle(1000)
    dataset = dataset.batch(config["batch_size"])

    return dataset


def val_data_creator(config):
    global test_images, test_labels
    dataset = tf.data.Dataset.from_tensor_slices((test_images, test_labels))
    dataset = dataset.repeat()
    dataset = dataset.map(test_preprocess)
    dataset = dataset.batch(config["batch_size"])

    return dataset

# %% [markdown]
# ### 5.构建模型算法

# %%
def model_creator(config):
    model = tf.keras.Sequential(
        [tf.keras.layers.Conv2D(32, kernel_size=(3, 3), strides=(1, 1), activation='relu',
                                input_shape=image_shape, padding='same'),
         tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'),
         tf.keras.layers.Conv2D(64, kernel_size=(3, 3), strides=(1, 1), activation='relu',
                                padding='valid'),
         tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'),
         tf.keras.layers.Conv2D(64, kernel_size=(3, 3), strides=(1, 1), activation='relu',
                                padding='valid'),
         tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'),
         tf.keras.layers.Flatten(),
         tf.keras.layers.Dense(500, activation='relu'),
         tf.keras.layers.Dense(256, activation='relu'),
         tf.keras.layers.Dense(84, activation='relu'),
         tf.keras.layers.Dense(10, activation='softmax'),
         ]
    )


    model.compile(optimizer=tf.keras.optimizers.RMSprop(),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %% [markdown]
# ### 6.定义整个训练函数

# %%
def main(max_epoch):
    batch_size = 320
    config = {
        "batch_size": batch_size
    }

    est = Estimator.from_keras(model_creator, config=config, workers_per_node=2)

    stats = est.fit(train_data_creator,
                    epochs=max_epoch,
                    steps_per_epoch=60000 // batch_size,
                    validation_data_creator=val_data_creator,
                    validation_steps=10000 // batch_size)

    print(stats)
    est.save("/tmp/cifar10_keras.ckpt")
    est.restore("/tmp/cifar10_keras.ckpt")
    stats = est.evaluate(val_data_creator, steps=10000 // batch_size)
    print(stats)

# %% [markdown]
# ### 7.基于Orca on yarn模式训练模型

# %%
cluster_mode = "yarn"
if cluster_mode == "local":
    init_orca_context(cluster_mode="local", cores=4, init_ray_on_spark=True)
elif cluster_mode == "yarn":
    init_orca_context(cluster_mode="yarn-client", num_nodes=2, cores=2,
                      init_ray_on_spark=True, memory="6g", driver_memory="6g",hadoop_user_name='hdfs', hadoop_conf="/etc/hadoop/3.0.1.0-187/0/")

main(5)
# Out:
# Initializing orca context
# Current pyspark location is : /root/anaconda3/envs/zoo-tf2.3/lib/python3.6/site-packages/pyspark/__init__.py
# Initializing SparkContext for yarn-client mode
# Start to pack current python env
# Packing has been completed: /tmp/tmpkdmyvtd0/python_env.tar.gz
# pyspark_submit_args is: --master yarn --deploy-mode client --archives /tmp/tmpkdmyvtd0/python_env.tar.gz#python_env --driver-cores 4 --driver-memory 6g --num-executors 2 --executor-cores 2 --executor-memory 6g --driver-class-path /root/anaconda3/envs/zoo-tf2.3/lib/python3.6/site-packages/zoo/share/lib/analytics-zoo-bigdl_0.12.1-spark_2.4.3-0.9.0-SNAPSHOT-jar-with-dependencies.jar:/root/anaconda3/envs/zoo-tf2.3/lib/python3.6/site-packages/bigdl/share/lib/bigdl-0.12.1-jar-with-dependencies.jar pyspark-shell
# JavaGatewayServer has been successfully launched on executors
# Start to launch ray on cluster
# Start to launch ray driver on local
# Executing command: ray start --address 10.180.210.172:36944 --redis-password 123456 --num-cpus 0 --node-ip-address 10.180.210.218
# 2020-12-09 08:25:55,538	WARNING worker.py:792 -- When connecting to an existing cluster, _internal_config must match the cluster's _internal_config.
# 2020-12-09 08:25:55,465	INFO scripts.py:429 -- Using IP address 10.180.210.218 for this node.
# 2020-12-09 08:25:55,470	INFO resource_spec.py:212 -- Starting Ray with 17.14 GiB memory available for workers and up to 7.36 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-12-09 08:25:55,471	WARNING services.py:1470 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 67108864 bytes available. This may slow down performance! You may be able to free up space by deleting files in /dev/shm or terminating any running plasma_store_server processes. If you are inside a Docker container, you may need to pass an argument with the flag '--shm-size' to 'docker run'.
# 2020-12-09 08:25:55,485	INFO scripts.py:438 --
# Started Ray on this node. If you wish to terminate the processes that have been started, run
#
#     ray stop
#
#
# {'node_ip_address': '10.180.210.218', 'redis_address': '10.180.210.172:36944', 'object_store_address': '/tmp/ray/session_2020-12-09_16-25-46_022007_6293/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2020-12-09_16-25-46_022007_6293/sockets/raylet', 'webui_url': 'localhost:8265', 'session_dir': '/tmp/ray/session_2020-12-09_16-25-46_022007_6293'}
# (pid=6345, ip=10.180.210.172) Prepending /var/lib/docker/hadoop/yarn/local/usercache/hdfs/appcache/application_1607477474145_0020/container_1607477474145_0020_01_000002/python_env/lib/python3.6/site-packages/bigdl/share/conf/spark-bigdl.conf to sys.path
# (pid=6345, ip=10.180.210.172) Prepending /var/lib/docker/hadoop/yarn/local/usercache/hdfs/appcache/application_1607477474145_0020/container_1607477474145_0020_01_000002/python_env/lib/python3.6/site-packages/zoo/share/conf/spark-analytics-zoo.conf to sys.path
# (pid=6344, ip=10.180.210.172) Prepending /var/lib/docker/hadoop/yarn/local/usercache/hdfs/appcache/application_1607477474145_0020/container_1607477474145_0020_01_000002/python_env/lib/python3.6/site-packages/bigdl/share/conf/spark-bigdl.conf to sys.path
# (pid=6344, ip=10.180.210.172) Prepending /var/lib/docker/hadoop/yarn/local/usercache/hdfs/appcache/application_1607477474145_0020/container_1607477474145_0020_01_000002/python_env/lib/python3.6/site-packages/zoo/share/conf/spark-analytics-zoo.conf to sys.path
# (pid=6412, ip=10.180.210.172) Prepending /var/lib/docker/hadoop/yarn/local/usercache/hdfs/appcache/application_1607477474145_0020/container_1607477474145_0020_01_000003/python_env/lib/python3.6/site-packages/bigdl/share/conf/spark-bigdl.conf to sys.path
# (pid=6412, ip=10.180.210.172) Prepending /var/lib/docker/hadoop/yarn/local/usercache/hdfs/appcache/application_1607477474145_0020/container_1607477474145_0020_01_000003/python_env/lib/python3.6/site-packages/zoo/share/conf/spark-analytics-zoo.conf to sys.path
# (pid=6411, ip=10.180.210.172) Prepending /var/lib/docker/hadoop/yarn/local/usercache/hdfs/appcache/application_1607477474145_0020/container_1607477474145_0020_01_000003/python_env/lib/python3.6/site-packages/bigdl/share/conf/spark-bigdl.conf to sys.path
# (pid=6411, ip=10.180.210.172) Prepending /var/lib/docker/hadoop/yarn/local/usercache/hdfs/appcache/application_1607477474145_0020/container_1607477474145_0020_01_000003/python_env/lib/python3.6/site-packages/zoo/share/conf/spark-analytics-zoo.conf to sys.path
# (pid=6345, ip=10.180.210.172) 2020-12-09 16:25:56.061396: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: python_env/lib:python_env/lib/python3.6/lib-dynload:
# (pid=6345, ip=10.180.210.172) 2020-12-09 16:25:56.061449: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# (pid=6344, ip=10.180.210.172) 2020-12-09 16:25:56.061396: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: python_env/lib:python_env/lib/python3.6/lib-dynload:
# (pid=6344, ip=10.180.210.172) 2020-12-09 16:25:56.061449: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# (pid=6412, ip=10.180.210.172) 2020-12-09 16:25:56.061396: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: python_env/lib:python_env/lib/python3.6/lib-dynload:
# (pid=6412, ip=10.180.210.172) 2020-12-09 16:25:56.061449: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# (pid=6411, ip=10.180.210.172) 2020-12-09 16:25:56.086298: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: python_env/lib:python_env/lib/python3.6/lib-dynload:
# (pid=6411, ip=10.180.210.172) 2020-12-09 16:25:56.086334: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# (pid=6345, ip=10.180.210.172) 2020-12-09 16:25:57.573972: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: python_env/lib:python_env/lib/python3.6/lib-dynload:
# (pid=6345, ip=10.180.210.172) 2020-12-09 16:25:57.574009: W tensorflow/stream_executor/cuda/cuda_driver.cc:312] failed call to cuInit: UNKNOWN ERROR (303)
# (pid=6345, ip=10.180.210.172) 2020-12-09 16:25:57.574037: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (worker): /proc/driver/nvidia/version does not exist
# (pid=6345, ip=10.180.210.172) 2020-12-09 16:25:57.574420: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# (pid=6345, ip=10.180.210.172) To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (pid=6345, ip=10.180.210.172) 2020-12-09 16:25:57.582069: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2095074999 Hz
# (pid=6345, ip=10.180.210.172) 2020-12-09 16:25:57.582191: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55567e727920 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# (pid=6345, ip=10.180.210.172) 2020-12-09 16:25:57.582216: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# (pid=6344, ip=10.180.210.172) 2020-12-09 16:25:57.573184: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: python_env/lib:python_env/lib/python3.6/lib-dynload:
# (pid=6344, ip=10.180.210.172) 2020-12-09 16:25:57.573220: W tensorflow/stream_executor/cuda/cuda_driver.cc:312] failed call to cuInit: UNKNOWN ERROR (303)
# (pid=6344, ip=10.180.210.172) 2020-12-09 16:25:57.573242: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (worker): /proc/driver/nvidia/version does not exist
# (pid=6344, ip=10.180.210.172) 2020-12-09 16:25:57.573573: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# (pid=6344, ip=10.180.210.172) To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (pid=6344, ip=10.180.210.172) 2020-12-09 16:25:57.581443: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2095074999 Hz
# (pid=6344, ip=10.180.210.172) 2020-12-09 16:25:57.581574: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5647b1a10be0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# (pid=6344, ip=10.180.210.172) 2020-12-09 16:25:57.581598: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# (pid=6344, ip=10.180.210.172) 2020-12-09 16:25:57.589327: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.180.210.172:56677, 1 -> 10.180.210.172:38269, 2 -> 10.180.210.172:50069, 3 -> 10.180.210.172:38118}
# (pid=6344, ip=10.180.210.172) 2020-12-09 16:25:57.589652: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:405] Started server with target: grpc://10.180.210.172:38269
# (pid=6412, ip=10.180.210.172) 2020-12-09 16:25:57.574493: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: python_env/lib:python_env/lib/python3.6/lib-dynload:
# (pid=6412, ip=10.180.210.172) 2020-12-09 16:25:57.574525: W tensorflow/stream_executor/cuda/cuda_driver.cc:312] failed call to cuInit: UNKNOWN ERROR (303)
# (pid=6412, ip=10.180.210.172) 2020-12-09 16:25:57.574548: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (worker): /proc/driver/nvidia/version does not exist
# (pid=6412, ip=10.180.210.172) 2020-12-09 16:25:57.574873: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# (pid=6412, ip=10.180.210.172) To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (pid=6412, ip=10.180.210.172) 2020-12-09 16:25:57.583671: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2095074999 Hz
# (pid=6412, ip=10.180.210.172) 2020-12-09 16:25:57.583788: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x559582ab8630 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# (pid=6412, ip=10.180.210.172) 2020-12-09 16:25:57.583812: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# (pid=6411, ip=10.180.210.172) 2020-12-09 16:25:57.573810: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: python_env/lib:python_env/lib/python3.6/lib-dynload:
# (pid=6411, ip=10.180.210.172) 2020-12-09 16:25:57.573876: W tensorflow/stream_executor/cuda/cuda_driver.cc:312] failed call to cuInit: UNKNOWN ERROR (303)
# (pid=6411, ip=10.180.210.172) 2020-12-09 16:25:57.573925: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (worker): /proc/driver/nvidia/version does not exist
# (pid=6411, ip=10.180.210.172) 2020-12-09 16:25:57.574578: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# (pid=6411, ip=10.180.210.172) To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (pid=6411, ip=10.180.210.172) 2020-12-09 16:25:57.584683: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2095074999 Hz
# (pid=6411, ip=10.180.210.172) 2020-12-09 16:25:57.584805: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55d6f20b9490 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# (pid=6411, ip=10.180.210.172) 2020-12-09 16:25:57.584829: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# (pid=6345, ip=10.180.210.172) 2020-12-09 16:25:57.592450: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.180.210.172:56677, 1 -> 10.180.210.172:38269, 2 -> 10.180.210.172:50069, 3 -> 10.180.210.172:38118}
# (pid=6345, ip=10.180.210.172) 2020-12-09 16:25:57.592965: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:405] Started server with target: grpc://10.180.210.172:50069
# (pid=6412, ip=10.180.210.172) 2020-12-09 16:25:57.593678: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.180.210.172:56677, 1 -> 10.180.210.172:38269, 2 -> 10.180.210.172:50069, 3 -> 10.180.210.172:38118}
# (pid=6412, ip=10.180.210.172) 2020-12-09 16:25:57.594034: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:405] Started server with target: grpc://10.180.210.172:38118
# (pid=6411, ip=10.180.210.172) 2020-12-09 16:25:57.593978: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.180.210.172:56677, 1 -> 10.180.210.172:38269, 2 -> 10.180.210.172:50069, 3 -> 10.180.210.172:38118}
# (pid=6411, ip=10.180.210.172) 2020-12-09 16:25:57.594891: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:405] Started server with target: grpc://10.180.210.172:56677
# (pid=6411, ip=10.180.210.172) WARNING:tensorflow:AutoGraph could not transform <function train_preprocess at 0x7f8a77f2f400> and will run it as-is.
# (pid=6411, ip=10.180.210.172) Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# (pid=6411, ip=10.180.210.172) Cause: Unable to locate the source code of <function train_preprocess at 0x7f8a77f2f400>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# (pid=6411, ip=10.180.210.172) To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (pid=6411, ip=10.180.210.172) WARNING:tensorflow:AutoGraph could not transform <function test_preprocess at 0x7f8a7c696ea0> and will run it as-is.
# (pid=6411, ip=10.180.210.172) Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# (pid=6411, ip=10.180.210.172) Cause: Unable to locate the source code of <function test_preprocess at 0x7f8a7c696ea0>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# (pid=6411, ip=10.180.210.172) To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (pid=6411, ip=10.180.210.172) WARNING:tensorflow:`eval_fn` is not passed in. The `worker_fn` will be used if an "evaluator" task exists in the cluster.
# (pid=6411, ip=10.180.210.172) WARNING:tensorflow:`eval_strategy` is not passed in. No distribution strategy will be used for evaluation.
# (pid=6411, ip=10.180.210.172) 2020-12-09 16:26:00.301020: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:521] In AUTO-mode, and switching to DATA-based sharding, instead of FILE-based sharding as we cannot find appropriate reader dataset op(s) to shard. Error: Found an unshardable source dataset: name: "TensorSliceDataset/_2"
# (pid=6411, ip=10.180.210.172) op: "TensorSliceDataset"
# (pid=6411, ip=10.180.210.172) input: "Placeholder/_0"
# (pid=6411, ip=10.180.210.172) input: "Placeholder/_1"
# (pid=6411, ip=10.180.210.172) attr {
# (pid=6411, ip=10.180.210.172)   key: "Toutput_types"
# (pid=6411, ip=10.180.210.172)   value {
# (pid=6411, ip=10.180.210.172)     list {
# (pid=6411, ip=10.180.210.172)       type: DT_UINT8
# (pid=6411, ip=10.180.210.172)       type: DT_UINT8
# (pid=6411, ip=10.180.210.172)     }
# (pid=6411, ip=10.180.210.172)   }
# (pid=6411, ip=10.180.210.172) }
# (pid=6411, ip=10.180.210.172) attr {
# (pid=6411, ip=10.180.210.172)   key: "output_shapes"
# (pid=6411, ip=10.180.210.172)   value {
# (pid=6411, ip=10.180.210.172)     list {
# (pid=6411, ip=10.180.210.172)       shape {
# (pid=6411, ip=10.180.210.172)         dim {
# (pid=6411, ip=10.180.210.172)           size: 32
# (pid=6411, ip=10.180.210.172)         }
# (pid=6411, ip=10.180.210.172)         dim {
# (pid=6411, ip=10.180.210.172)           size: 32
# (pid=6411, ip=10.180.210.172)         }
# (pid=6411, ip=10.180.210.172)         dim {
# (pid=6411, ip=10.180.210.172)           size: 3
# (pid=6411, ip=10.180.210.172)         }
# (pid=6411, ip=10.180.210.172)       }
# (pid=6411, ip=10.180.210.172)       shape {
# (pid=6411, ip=10.180.210.172)         dim {
# (pid=6411, ip=10.180.210.172)           size: 1
# (pid=6411, ip=10.180.210.172)         }
# (pid=6411, ip=10.180.210.172)       }
# (pid=6411, ip=10.180.210.172)     }
# (pid=6411, ip=10.180.210.172)   }
# (pid=6411, ip=10.180.210.172) }
# (pid=6411, ip=10.180.210.172)
# (pid=6411, ip=10.180.210.172) Epoch 1/5
# (pid=6411, ip=10.180.210.172) WARNING:tensorflow:From /var/lib/docker/hadoop/yarn/local/usercache/hdfs/appcache/application_1607477474145_0020/container_1607477474145_0020_01_000003/python_env/lib/python3.6/site-packages/tensorflow/python/data/ops/multi_device_iterator_ops.py:601: get_next_as_optional (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# (pid=6411, ip=10.180.210.172) Instructions for updating:
# (pid=6411, ip=10.180.210.172) Use `tf.data.Iterator.get_next_as_optional()` instead.
# (pid=6344, ip=10.180.210.172) WARNING:tensorflow:AutoGraph could not transform <function train_preprocess at 0x7fac53450400> and will run it as-is.
# (pid=6344, ip=10.180.210.172) Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# (pid=6344, ip=10.180.210.172) Cause: Unable to locate the source code of <function train_preprocess at 0x7fac53450400>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# (pid=6344, ip=10.180.210.172) To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (pid=6344, ip=10.180.210.172) WARNING:tensorflow:AutoGraph could not transform <function test_preprocess at 0x7fac57bb7ea0> and will run it as-is.
# (pid=6344, ip=10.180.210.172) Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# (pid=6344, ip=10.180.210.172) Cause: Unable to locate the source code of <function test_preprocess at 0x7fac57bb7ea0>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# (pid=6344, ip=10.180.210.172) To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (pid=6344, ip=10.180.210.172) WARNING:tensorflow:`eval_fn` is not passed in. The `worker_fn` will be used if an "evaluator" task exists in the cluster.
# (pid=6344, ip=10.180.210.172) WARNING:tensorflow:`eval_strategy` is not passed in. No distribution strategy will be used for evaluation.
# (pid=6344, ip=10.180.210.172) 2020-12-09 16:26:02.106785: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:521] In AUTO-mode, and switching to DATA-based sharding, instead of FILE-based sharding as we cannot find appropriate reader dataset op(s) to shard. Error: Found an unshardable source dataset: name: "TensorSliceDataset/_2"
# (pid=6344, ip=10.180.210.172) op: "TensorSliceDataset"
# (pid=6344, ip=10.180.210.172) input: "Placeholder/_0"
# (pid=6344, ip=10.180.210.172) input: "Placeholder/_1"
# (pid=6344, ip=10.180.210.172) attr {
# (pid=6344, ip=10.180.210.172)   key: "Toutput_types"
# (pid=6344, ip=10.180.210.172)   value {
# (pid=6344, ip=10.180.210.172)     list {
# (pid=6344, ip=10.180.210.172)       type: DT_UINT8
# (pid=6344, ip=10.180.210.172)       type: DT_UINT8
# (pid=6344, ip=10.180.210.172)     }
# (pid=6344, ip=10.180.210.172)   }
# (pid=6344, ip=10.180.210.172) }
# (pid=6344, ip=10.180.210.172) attr {
# (pid=6344, ip=10.180.210.172)   key: "output_shapes"
# (pid=6344, ip=10.180.210.172)   value {
# (pid=6344, ip=10.180.210.172)     list {
# (pid=6344, ip=10.180.210.172)       shape {
# (pid=6344, ip=10.180.210.172)         dim {
# (pid=6344, ip=10.180.210.172)           size: 32
# (pid=6344, ip=10.180.210.172)         }
# (pid=6344, ip=10.180.210.172)         dim {
# (pid=6344, ip=10.180.210.172)           size: 32
# (pid=6344, ip=10.180.210.172)         }
# (pid=6344, ip=10.180.210.172)         dim {
# (pid=6344, ip=10.180.210.172)           size: 3
# (pid=6344, ip=10.180.210.172)         }
# (pid=6344, ip=10.180.210.172)       }
# (pid=6344, ip=10.180.210.172)       shape {
# (pid=6344, ip=10.180.210.172)         dim {
# (pid=6344, ip=10.180.210.172)           size: 1
# (pid=6344, ip=10.180.210.172)         }
# (pid=6344, ip=10.180.210.172)       }
# (pid=6344, ip=10.180.210.172)     }
# (pid=6344, ip=10.180.210.172)   }
# (pid=6344, ip=10.180.210.172) }
# (pid=6344, ip=10.180.210.172)
# (pid=6344, ip=10.180.210.172) WARNING:tensorflow:From /var/lib/docker/hadoop/yarn/local/usercache/hdfs/appcache/application_1607477474145_0020/container_1607477474145_0020_01_000002/python_env/lib/python3.6/site-packages/tensorflow/python/data/ops/multi_device_iterator_ops.py:601: get_next_as_optional (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# (pid=6344, ip=10.180.210.172) Instructions for updating:
# (pid=6344, ip=10.180.210.172) Use `tf.data.Iterator.get_next_as_optional()` instead.
# (pid=6345, ip=10.180.210.172) WARNING:tensorflow:AutoGraph could not transform <function train_preprocess at 0x7f014529d400> and will run it as-is.
# (pid=6345, ip=10.180.210.172) Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# (pid=6345, ip=10.180.210.172) Cause: Unable to locate the source code of <function train_preprocess at 0x7f014529d400>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# (pid=6345, ip=10.180.210.172) To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (pid=6345, ip=10.180.210.172) WARNING:tensorflow:AutoGraph could not transform <function test_preprocess at 0x7f0149a04ea0> and will run it as-is.
# (pid=6345, ip=10.180.210.172) Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# (pid=6345, ip=10.180.210.172) Cause: Unable to locate the source code of <function test_preprocess at 0x7f0149a04ea0>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# (pid=6345, ip=10.180.210.172) To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (pid=6345, ip=10.180.210.172) WARNING:tensorflow:`eval_fn` is not passed in. The `worker_fn` will be used if an "evaluator" task exists in the cluster.
# (pid=6345, ip=10.180.210.172) WARNING:tensorflow:`eval_strategy` is not passed in. No distribution strategy will be used for evaluation.
# (pid=6345, ip=10.180.210.172) 2020-12-09 16:26:03.671321: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:521] In AUTO-mode, and switching to DATA-based sharding, instead of FILE-based sharding as we cannot find appropriate reader dataset op(s) to shard. Error: Found an unshardable source dataset: name: "TensorSliceDataset/_2"
# (pid=6345, ip=10.180.210.172) op: "TensorSliceDataset"
# (pid=6345, ip=10.180.210.172) input: "Placeholder/_0"
# (pid=6345, ip=10.180.210.172) input: "Placeholder/_1"
# (pid=6345, ip=10.180.210.172) attr {
# (pid=6345, ip=10.180.210.172)   key: "Toutput_types"
# (pid=6345, ip=10.180.210.172)   value {
# (pid=6345, ip=10.180.210.172)     list {
# (pid=6345, ip=10.180.210.172)       type: DT_UINT8
# (pid=6345, ip=10.180.210.172)       type: DT_UINT8
# (pid=6345, ip=10.180.210.172)     }
# (pid=6345, ip=10.180.210.172)   }
# (pid=6345, ip=10.180.210.172) }
# (pid=6345, ip=10.180.210.172) attr {
# (pid=6345, ip=10.180.210.172)   key: "output_shapes"
# (pid=6345, ip=10.180.210.172)   value {
# (pid=6345, ip=10.180.210.172)     list {
# (pid=6345, ip=10.180.210.172)       shape {
# (pid=6345, ip=10.180.210.172)         dim {
# (pid=6345, ip=10.180.210.172)           size: 32
# (pid=6345, ip=10.180.210.172)         }
# (pid=6345, ip=10.180.210.172)         dim {
# (pid=6345, ip=10.180.210.172)           size: 32
# (pid=6345, ip=10.180.210.172)         }
# (pid=6345, ip=10.180.210.172)         dim {
# (pid=6345, ip=10.180.210.172)           size: 3
# (pid=6345, ip=10.180.210.172)         }
# (pid=6345, ip=10.180.210.172)       }
# (pid=6345, ip=10.180.210.172)       shape {
# (pid=6345, ip=10.180.210.172)         dim {
# (pid=6345, ip=10.180.210.172)           size: 1
# (pid=6345, ip=10.180.210.172)         }
# (pid=6345, ip=10.180.210.172)       }
# (pid=6345, ip=10.180.210.172)     }
# (pid=6345, ip=10.180.210.172)   }
# (pid=6345, ip=10.180.210.172) }
# (pid=6345, ip=10.180.210.172)
# (pid=6345, ip=10.180.210.172) WARNING:tensorflow:From /var/lib/docker/hadoop/yarn/local/usercache/hdfs/appcache/application_1607477474145_0020/container_1607477474145_0020_01_000002/python_env/lib/python3.6/site-packages/tensorflow/python/data/ops/multi_device_iterator_ops.py:601: get_next_as_optional (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# (pid=6345, ip=10.180.210.172) Instructions for updating:
# (pid=6345, ip=10.180.210.172) Use `tf.data.Iterator.get_next_as_optional()` instead.
# (pid=6412, ip=10.180.210.172) WARNING:tensorflow:AutoGraph could not transform <function train_preprocess at 0x7f8e48182400> and will run it as-is.
# (pid=6412, ip=10.180.210.172) Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# (pid=6412, ip=10.180.210.172) Cause: Unable to locate the source code of <function train_preprocess at 0x7f8e48182400>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# (pid=6412, ip=10.180.210.172) To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (pid=6412, ip=10.180.210.172) WARNING:tensorflow:AutoGraph could not transform <function test_preprocess at 0x7f8e4c8e9ea0> and will run it as-is.
# (pid=6412, ip=10.180.210.172) Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# (pid=6412, ip=10.180.210.172) Cause: Unable to locate the source code of <function test_preprocess at 0x7f8e4c8e9ea0>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# (pid=6412, ip=10.180.210.172) To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (pid=6412, ip=10.180.210.172) WARNING:tensorflow:`eval_fn` is not passed in. The `worker_fn` will be used if an "evaluator" task exists in the cluster.
# (pid=6412, ip=10.180.210.172) WARNING:tensorflow:`eval_strategy` is not passed in. No distribution strategy will be used for evaluation.
# (pid=6412, ip=10.180.210.172) 2020-12-09 16:26:05.349258: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:521] In AUTO-mode, and switching to DATA-based sharding, instead of FILE-based sharding as we cannot find appropriate reader dataset op(s) to shard. Error: Found an unshardable source dataset: name: "TensorSliceDataset/_2"
# (pid=6412, ip=10.180.210.172) op: "TensorSliceDataset"
# (pid=6412, ip=10.180.210.172) input: "Placeholder/_0"
# (pid=6412, ip=10.180.210.172) input: "Placeholder/_1"
# (pid=6412, ip=10.180.210.172) attr {
# (pid=6412, ip=10.180.210.172)   key: "Toutput_types"
# (pid=6412, ip=10.180.210.172)   value {
# (pid=6412, ip=10.180.210.172)     list {
# (pid=6412, ip=10.180.210.172)       type: DT_UINT8
# (pid=6412, ip=10.180.210.172)       type: DT_UINT8
# (pid=6412, ip=10.180.210.172)     }
# (pid=6412, ip=10.180.210.172)   }
# (pid=6412, ip=10.180.210.172) }
# (pid=6412, ip=10.180.210.172) attr {
# (pid=6412, ip=10.180.210.172)   key: "output_shapes"
# (pid=6412, ip=10.180.210.172)   value {
# (pid=6412, ip=10.180.210.172)     list {
# (pid=6412, ip=10.180.210.172)       shape {
# (pid=6412, ip=10.180.210.172)         dim {
# (pid=6412, ip=10.180.210.172)           size: 32
# (pid=6412, ip=10.180.210.172)         }
# (pid=6412, ip=10.180.210.172)         dim {
# (pid=6412, ip=10.180.210.172)           size: 32
# (pid=6412, ip=10.180.210.172)         }
# (pid=6412, ip=10.180.210.172)         dim {
# (pid=6412, ip=10.180.210.172)           size: 3
# (pid=6412, ip=10.180.210.172)         }
# (pid=6412, ip=10.180.210.172)       }
# (pid=6412, ip=10.180.210.172)       shape {
# (pid=6412, ip=10.180.210.172)         dim {
# (pid=6412, ip=10.180.210.172)           size: 1
# (pid=6412, ip=10.180.210.172)         }
# (pid=6412, ip=10.180.210.172)       }
# (pid=6412, ip=10.180.210.172)     }
# (pid=6412, ip=10.180.210.172)   }
# (pid=6412, ip=10.180.210.172) }
# (pid=6412, ip=10.180.210.172)
# (pid=6412, ip=10.180.210.172) WARNING:tensorflow:From /var/lib/docker/hadoop/yarn/local/usercache/hdfs/appcache/application_1607477474145_0020/container_1607477474145_0020_01_000003/python_env/lib/python3.6/site-packages/tensorflow/python/data/ops/multi_device_iterator_ops.py:601: get_next_as_optional (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# (pid=6412, ip=10.180.210.172) Instructions for updating:
# (pid=6412, ip=10.180.210.172) Use `tf.data.Iterator.get_next_as_optional()` instead.
#   1/187 [..............................] - ETA: 0s - loss: 2.3031 - accuracy: 0.1187
#   2/187 [..............................] - ETA: 17s - loss: 2.3192 - accuracy: 0.1016
#   3/187 [..............................] - ETA: 23s - loss: 2.3128 - accuracy: 0.1042
#   4/187 [..............................] - ETA: 25s - loss: 2.3086 - accuracy: 0.1039
#   5/187 [..............................] - ETA: 26s - loss: 2.3094 - accuracy: 0.1063
#   6/187 [..............................] - ETA: 27s - loss: 2.3079 - accuracy: 0.1104
#   7/187 [>.............................] - ETA: 29s - loss: 2.3072 - accuracy: 0.1076
#   8/187 [>.............................] - ETA: 28s - loss: 2.3064 - accuracy: 0.1109
#   9/187 [>.............................] - ETA: 28s - loss: 2.3050 - accuracy: 0.1115
#  10/187 [>.............................] - ETA: 28s - loss: 2.3032 - accuracy: 0.1131
#  11/187 [>.............................] - ETA: 28s - loss: 2.3058 - accuracy: 0.1114
#  12/187 [>.............................] - ETA: 29s - loss: 2.3054 - accuracy: 0.1141
#  13/187 [=>............................] - ETA: 29s - loss: 2.3046 - accuracy: 0.1137
#  14/187 [=>............................] - ETA: 29s - loss: 2.3033 - accuracy: 0.1150
#  15/187 [=>............................] - ETA: 29s - loss: 2.3007 - accuracy: 0.1198
#  16/187 [=>............................] - ETA: 29s - loss: 2.2999 - accuracy: 0.1209
#  17/187 [=>............................] - ETA: 29s - loss: 2.3035 - accuracy: 0.1191
#  18/187 [=>............................] - ETA: 29s - loss: 2.3034 - accuracy: 0.1184
#  19/187 [==>...........................] - ETA: 28s - loss: 2.3029 - accuracy: 0.1192
#  20/187 [==>...........................] - ETA: 29s - loss: 2.3020 - accuracy: 0.1189
#  21/187 [==>...........................] - ETA: 29s - loss: 2.3009 - accuracy: 0.1210
#  22/187 [==>...........................] - ETA: 28s - loss: 2.2999 - accuracy: 0.1199
#  23/187 [==>...........................] - ETA: 28s - loss: 2.2993 - accuracy: 0.1217
#  24/187 [==>...........................] - ETA: 28s - loss: 2.2974 - accuracy: 0.1234
#  25/187 [===>..........................] - ETA: 28s - loss: 2.2999 - accuracy: 0.1225
# 173/187 [==========================>...] - ETA: 2s - loss: 2.1965 - accuracy: 0.1846
# ...
# 169/187 [==========================>...] - ETA: 3s - loss: 1.6848 - accuracy: 0.3954
# 170/187 [==========================>...] - ETA: 3s - loss: 1.6855 - accuracy: 0.3951
# 171/187 [==========================>...] - ETA: 2s - loss: 1.6851 - accuracy: 0.3951
# 172/187 [==========================>...] - ETA: 2s - loss: 1.6854 - accuracy: 0.3949
# 173/187 [==========================>...] - ETA: 2s - loss: 1.6844 - accuracy: 0.3953
# 174/187 [==========================>...] - ETA: 2s - loss: 1.6836 - accuracy: 0.3956
# 175/187 [===========================>..] - ETA: 2s - loss: 1.6837 - accuracy: 0.3954
# 176/187 [===========================>..] - ETA: 1s - loss: 1.6827 - accuracy: 0.3959
# 177/187 [===========================>..] - ETA: 1s - loss: 1.6822 - accuracy: 0.3962
# 178/187 [===========================>..] - ETA: 1s - loss: 1.6813 - accuracy: 0.3965
# 179/187 [===========================>..] - ETA: 1s - loss: 1.6803 - accuracy: 0.3969
# 180/187 [===========================>..] - ETA: 1s - loss: 1.6802 - accuracy: 0.3970
# 181/187 [============================>.] - ETA: 1s - loss: 1.6799 - accuracy: 0.3970
# 182/187 [============================>.] - ETA: 0s - loss: 1.6794 - accuracy: 0.3971
# 183/187 [============================>.] - ETA: 0s - loss: 1.6786 - accuracy: 0.3975
# 184/187 [============================>.] - ETA: 0s - loss: 1.6785 - accuracy: 0.3975
# 185/187 [============================>.] - ETA: 0s - loss: 1.6787 - accuracy: 0.3974
# 186/187 [============================>.] - ETA: 0s - loss: 1.6791 - accuracy: 0.3972
# 187/187 [==============================] - ETA: 0s - loss: 1.6792 - accuracy: 0.3973
# 187/187 [==============================] - 35s 188ms/step - loss: 1.6792 - accuracy: 0.3973 - val_loss: 1.5847 - val_accuracy: 0.4407
# {'train_loss': 1.6792051792144775, 'train_accuracy': 0.39730948209762573, 'train_val_loss': 1.5846550464630127, 'train_val_accuracy': 0.44072580337524414}
# (pid=6411, ip=10.180.210.172) WARNING:tensorflow:AutoGraph could not transform <function test_preprocess at 0x7f882779ae18> and will run it as-is.
# (pid=6411, ip=10.180.210.172) Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# (pid=6411, ip=10.180.210.172) Cause: Unable to locate the source code of <function test_preprocess at 0x7f882779ae18>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# (pid=6411, ip=10.180.210.172) To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (pid=6411, ip=10.180.210.172) WARNING:tensorflow:`eval_fn` is not passed in. The `worker_fn` will be used if an "evaluator" task exists in the cluster.
# (pid=6411, ip=10.180.210.172) WARNING:tensorflow:`eval_strategy` is not passed in. No distribution strategy will be used for evaluation.
# (pid=6411, ip=10.180.210.172) 2020-12-09 16:29:08.245938: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:521] In AUTO-mode, and switching to DATA-based sharding, instead of FILE-based sharding as we cannot find appropriate reader dataset op(s) to shard. Error: Found an unshardable source dataset: name: "TensorSliceDataset/_2"
# (pid=6411, ip=10.180.210.172) op: "TensorSliceDataset"
# (pid=6411, ip=10.180.210.172) input: "Placeholder/_0"
# (pid=6411, ip=10.180.210.172) input: "Placeholder/_1"
# (pid=6411, ip=10.180.210.172) attr {
# (pid=6411, ip=10.180.210.172)   key: "Toutput_types"
# (pid=6411, ip=10.180.210.172)   value {
# (pid=6411, ip=10.180.210.172)     list {
# (pid=6411, ip=10.180.210.172)       type: DT_UINT8
# (pid=6411, ip=10.180.210.172)       type: DT_UINT8
# (pid=6411, ip=10.180.210.172)     }
# (pid=6411, ip=10.180.210.172)   }
# (pid=6411, ip=10.180.210.172) }
# (pid=6411, ip=10.180.210.172) attr {
# (pid=6411, ip=10.180.210.172)   key: "output_shapes"
# (pid=6411, ip=10.180.210.172)   value {
# (pid=6411, ip=10.180.210.172)     list {
# (pid=6411, ip=10.180.210.172)       shape {
# (pid=6411, ip=10.180.210.172)         dim {
# (pid=6411, ip=10.180.210.172)           size: 32
# (pid=6411, ip=10.180.210.172)         }
# (pid=6411, ip=10.180.210.172)         dim {
# (pid=6411, ip=10.180.210.172)           size: 32
# (pid=6411, ip=10.180.210.172)         }
# (pid=6411, ip=10.180.210.172)         dim {
# (pid=6411, ip=10.180.210.172)           size: 3
# (pid=6411, ip=10.180.210.172)         }
# (pid=6411, ip=10.180.210.172)       }
# (pid=6411, ip=10.180.210.172)       shape {
# (pid=6411, ip=10.180.210.172)         dim {
# (pid=6411, ip=10.180.210.172)           size: 1
# (pid=6411, ip=10.180.210.172)         }
# (pid=6411, ip=10.180.210.172)       }
# (pid=6411, ip=10.180.210.172)     }
# (pid=6411, ip=10.180.210.172)   }
# (pid=6411, ip=10.180.210.172) }
# (pid=6411, ip=10.180.210.172)
# (pid=6344, ip=10.180.210.172) WARNING:tensorflow:AutoGraph could not transform <function test_preprocess at 0x7fac53450510> and will run it as-is.
# (pid=6344, ip=10.180.210.172) Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# (pid=6344, ip=10.180.210.172) Cause: Unable to locate the source code of <function test_preprocess at 0x7fac53450510>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# (pid=6344, ip=10.180.210.172) To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (pid=6344, ip=10.180.210.172) WARNING:tensorflow:`eval_fn` is not passed in. The `worker_fn` will be used if an "evaluator" task exists in the cluster.
# (pid=6344, ip=10.180.210.172) WARNING:tensorflow:`eval_strategy` is not passed in. No distribution strategy will be used for evaluation.
# (pid=6344, ip=10.180.210.172) 2020-12-09 16:29:08.499408: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:521] In AUTO-mode, and switching to DATA-based sharding, instead of FILE-based sharding as we cannot find appropriate reader dataset op(s) to shard. Error: Found an unshardable source dataset: name: "TensorSliceDataset/_2"
# (pid=6344, ip=10.180.210.172) op: "TensorSliceDataset"
# (pid=6344, ip=10.180.210.172) input: "Placeholder/_0"
# (pid=6344, ip=10.180.210.172) input: "Placeholder/_1"
# (pid=6344, ip=10.180.210.172) attr {
# (pid=6344, ip=10.180.210.172)   key: "Toutput_types"
# (pid=6344, ip=10.180.210.172)   value {
# (pid=6344, ip=10.180.210.172)     list {
# (pid=6344, ip=10.180.210.172)       type: DT_UINT8
# (pid=6344, ip=10.180.210.172)       type: DT_UINT8
# (pid=6344, ip=10.180.210.172)     }
# (pid=6344, ip=10.180.210.172)   }
# (pid=6344, ip=10.180.210.172) }
# (pid=6344, ip=10.180.210.172) attr {
# (pid=6344, ip=10.180.210.172)   key: "output_shapes"
# (pid=6344, ip=10.180.210.172)   value {
# (pid=6344, ip=10.180.210.172)     list {
# (pid=6344, ip=10.180.210.172)       shape {
# (pid=6344, ip=10.180.210.172)         dim {
# (pid=6344, ip=10.180.210.172)           size: 32
# (pid=6344, ip=10.180.210.172)         }
# (pid=6344, ip=10.180.210.172)         dim {
# (pid=6344, ip=10.180.210.172)           size: 32
# (pid=6344, ip=10.180.210.172)         }
# (pid=6344, ip=10.180.210.172)         dim {
# (pid=6344, ip=10.180.210.172)           size: 3
# (pid=6344, ip=10.180.210.172)         }
# (pid=6344, ip=10.180.210.172)       }
# (pid=6344, ip=10.180.210.172)       shape {
# (pid=6344, ip=10.180.210.172)         dim {
# (pid=6344, ip=10.180.210.172)           size: 1
# (pid=6344, ip=10.180.210.172)         }
# (pid=6344, ip=10.180.210.172)       }
# (pid=6344, ip=10.180.210.172)     }
# (pid=6344, ip=10.180.210.172)   }
# (pid=6344, ip=10.180.210.172) }
# (pid=6344, ip=10.180.210.172)
# (pid=6345, ip=10.180.210.172) WARNING:tensorflow:AutoGraph could not transform <function test_preprocess at 0x7f014529d510> and will run it as-is.
# (pid=6345, ip=10.180.210.172) Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# (pid=6345, ip=10.180.210.172) Cause: Unable to locate the source code of <function test_preprocess at 0x7f014529d510>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# (pid=6345, ip=10.180.210.172) To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (pid=6345, ip=10.180.210.172) WARNING:tensorflow:`eval_fn` is not passed in. The `worker_fn` will be used if an "evaluator" task exists in the cluster.
# (pid=6345, ip=10.180.210.172) WARNING:tensorflow:`eval_strategy` is not passed in. No distribution strategy will be used for evaluation.
# (pid=6345, ip=10.180.210.172) 2020-12-09 16:29:08.758681: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:521] In AUTO-mode, and switching to DATA-based sharding, instead of FILE-based sharding as we cannot find appropriate reader dataset op(s) to shard. Error: Found an unshardable source dataset: name: "TensorSliceDataset/_2"
# (pid=6345, ip=10.180.210.172) op: "TensorSliceDataset"
# (pid=6345, ip=10.180.210.172) input: "Placeholder/_0"
# (pid=6345, ip=10.180.210.172) input: "Placeholder/_1"
# (pid=6345, ip=10.180.210.172) attr {
# (pid=6345, ip=10.180.210.172)   key: "Toutput_types"
# (pid=6345, ip=10.180.210.172)   value {
# (pid=6345, ip=10.180.210.172)     list {
# (pid=6345, ip=10.180.210.172)       type: DT_UINT8
# (pid=6345, ip=10.180.210.172)       type: DT_UINT8
# (pid=6345, ip=10.180.210.172)     }
# (pid=6345, ip=10.180.210.172)   }
# (pid=6345, ip=10.180.210.172) }
# (pid=6345, ip=10.180.210.172) attr {
# (pid=6345, ip=10.180.210.172)   key: "output_shapes"
# (pid=6345, ip=10.180.210.172)   value {
# (pid=6345, ip=10.180.210.172)     list {
# (pid=6345, ip=10.180.210.172)       shape {
# (pid=6345, ip=10.180.210.172)         dim {
# (pid=6345, ip=10.180.210.172)           size: 32
# (pid=6345, ip=10.180.210.172)         }
# (pid=6345, ip=10.180.210.172)         dim {
# (pid=6345, ip=10.180.210.172)           size: 32
# (pid=6345, ip=10.180.210.172)         }
# (pid=6345, ip=10.180.210.172)         dim {
# (pid=6345, ip=10.180.210.172)           size: 3
# (pid=6345, ip=10.180.210.172)         }
# (pid=6345, ip=10.180.210.172)       }
# (pid=6345, ip=10.180.210.172)       shape {
# (pid=6345, ip=10.180.210.172)         dim {
# (pid=6345, ip=10.180.210.172)           size: 1
# (pid=6345, ip=10.180.210.172)         }
# (pid=6345, ip=10.180.210.172)       }
# (pid=6345, ip=10.180.210.172)     }
# (pid=6345, ip=10.180.210.172)   }
# (pid=6345, ip=10.180.210.172) }
# (pid=6345, ip=10.180.210.172)
# (pid=6412, ip=10.180.210.172) WARNING:tensorflow:AutoGraph could not transform <function test_preprocess at 0x7f8e48182510> and will run it as-is.
# (pid=6412, ip=10.180.210.172) Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# (pid=6412, ip=10.180.210.172) Cause: Unable to locate the source code of <function test_preprocess at 0x7f8e48182510>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# (pid=6412, ip=10.180.210.172) To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# (pid=6412, ip=10.180.210.172) WARNING:tensorflow:`eval_fn` is not passed in. The `worker_fn` will be used if an "evaluator" task exists in the cluster.
# (pid=6412, ip=10.180.210.172) WARNING:tensorflow:`eval_strategy` is not passed in. No distribution strategy will be used for evaluation.
# (pid=6412, ip=10.180.210.172) 2020-12-09 16:29:09.001083: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:521] In AUTO-mode, and switching to DATA-based sharding, instead of FILE-based sharding as we cannot find appropriate reader dataset op(s) to shard. Error: Found an unshardable source dataset: name: "TensorSliceDataset/_2"
# (pid=6412, ip=10.180.210.172) op: "TensorSliceDataset"
# (pid=6412, ip=10.180.210.172) input: "Placeholder/_0"
# (pid=6412, ip=10.180.210.172) input: "Placeholder/_1"
# (pid=6412, ip=10.180.210.172) attr {
# (pid=6412, ip=10.180.210.172)   key: "Toutput_types"
# (pid=6412, ip=10.180.210.172)   value {
# (pid=6412, ip=10.180.210.172)     list {
# (pid=6412, ip=10.180.210.172)       type: DT_UINT8
# (pid=6412, ip=10.180.210.172)       type: DT_UINT8
# (pid=6412, ip=10.180.210.172)     }
# (pid=6412, ip=10.180.210.172)   }
# (pid=6412, ip=10.180.210.172) }
# (pid=6412, ip=10.180.210.172) attr {
# (pid=6412, ip=10.180.210.172)   key: "output_shapes"
# (pid=6412, ip=10.180.210.172)   value {
# (pid=6412, ip=10.180.210.172)     list {
# (pid=6412, ip=10.180.210.172)       shape {
# (pid=6412, ip=10.180.210.172)         dim {
# (pid=6412, ip=10.180.210.172)           size: 32
# (pid=6412, ip=10.180.210.172)         }
# (pid=6412, ip=10.180.210.172)         dim {
# (pid=6412, ip=10.180.210.172)           size: 32
# (pid=6412, ip=10.180.210.172)         }
# (pid=6412, ip=10.180.210.172)         dim {
# (pid=6412, ip=10.180.210.172)           size: 3
# (pid=6412, ip=10.180.210.172)         }
# (pid=6412, ip=10.180.210.172)       }
# (pid=6412, ip=10.180.210.172)       shape {
# (pid=6412, ip=10.180.210.172)         dim {
# (pid=6412, ip=10.180.210.172)           size: 1
# (pid=6412, ip=10.180.210.172)         }
# (pid=6412, ip=10.180.210.172)       }
# (pid=6412, ip=10.180.210.172)     }
# (pid=6412, ip=10.180.210.172)   }
# (pid=6412, ip=10.180.210.172) }
# (pid=6412, ip=10.180.210.172)
#  1/31 [..............................] - ETA: 0s - loss: 1.5753 - accuracy: 0.4281
#  2/31 [>.............................] - ETA: 0s - loss: 1.5686 - accuracy: 0.4250
#  3/31 [=>............................] - ETA: 1s - loss: 1.5552 - accuracy: 0.4417
#  5/31 [===>..........................] - ETA: 1s - loss: 1.5503 - accuracy: 0.4469
#  6/31 [====>.........................] - ETA: 1s - loss: 1.5508 - accuracy: 0.4469
#  7/31 [=====>........................] - ETA: 1s - loss: 1.5548 - accuracy: 0.4473
#  9/31 [=======>......................] - ETA: 1s - loss: 1.5666 - accuracy: 0.4406
# 11/31 [=========>....................] - ETA: 0s - loss: 1.5709 - accuracy: 0.4426
# 13/31 [===========>..................] - ETA: 0s - loss: 1.5727 - accuracy: 0.4466
# 15/31 [=============>................] - ETA: 0s - loss: 1.5722 - accuracy: 0.4442
# 17/31 [===============>..............] - ETA: 0s - loss: 1.5755 - accuracy: 0.4421
# 18/31 [================>.............] - ETA: 0s - loss: 1.5771 - accuracy: 0.4424
# 20/31 [==================>...........] - ETA: 0s - loss: 1.5850 - accuracy: 0.4391
# 22/31 [====================>.........] - ETA: 0s - loss: 1.5896 - accuracy: 0.4371
# 23/31 [=====================>........] - ETA: 0s - loss: 1.5899 - accuracy: 0.4385
# 24/31 [======================>.......] - ETA: 0s - loss: 1.5919 - accuracy: 0.4380
# 26/31 [========================>.....] - ETA: 0s - loss: 1.5900 - accuracy: 0.4383
# 28/31 [==========================>...] - ETA: 0s - loss: 1.5873 - accuracy: 0.4403
# 29/31 [===========================>..] - ETA: 0s - loss: 1.5849 - accuracy: 0.4416
# 31/31 [==============================] - 2s 49ms/step - loss: 1.5847 - accuracy: 0.4407
# {'validation_loss': 1.5846550464630127, 'validation_accuracy': 0.44072580337524414}
